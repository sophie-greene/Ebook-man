# %%
import nltk
from ebooklib import epub 
from  comFunc import *

# %%
d_dir = '/media/sf_lbuntu/calibre/'
files = find('*.epub', d_dir)

# %%
book=epub.read_epub(files[0])

# %%
lst=[]
for b in book.get_items_of_type(9):
    lst.append ([b,b.get_content()])

# %%
f=files[0]
# !ebook-convert "$f" output.txt
# Out:
# 1% Converting input to HTML...
# InputFormatPlugin: EPUB Input running
# on /media/sf_lbuntu/calibre/Ursula Sinclair/Maze (2441)/Maze - Ursula Sinclair.epub
# Found HTML cover EPUB/titlepage.xhtml
# Parsing all content...
# 34% Running transforms on ebook...
# Merging user specified metadata...
# Detecting structure...
# Flattening CSS and remapping font sizes...
# Source base font size is 12.00000pt
# Removing fake margins...
# Cleaning up manifest...
# Trimming unused files from manifest...
# Creating TXT Output...
# 67% Running TXT Output plugin
# Converting XHTML to TXT...
# TXT output written to /home/some/repo/output.txt
# Output saved to   /home/some/repo/output.txt

# %%
txt=!cat output.txt

# %%
import string
nop='\t\n\r\x0b\x0c'
def stripnp(s):
    return ''.join(x for x in s if x in string.printable[:-5]+string.printable[-4])

# %%
s=(html2txt((lst[-5][1])))
txt=stripnp(s)
txt=" ".join(txt.replace('\n',' ').split()) 
nltk.FreqDist(txt.split())
# Out:
# FreqDist({'leaving': 2,
#           'hint': 2,
#           'those': 1,
#           'hated': 1,
#           'kissed': 7,
#           'You?': 1,
#           'underlying': 1,
#           'goes': 1,
#           'clothing': 1,
#           'call': 4,
#           'Now,': 1,
#           'press': 1,
#           'breakfast': 1,
#           'front': 1,
#           'told': 8,
#           'felt': 5,
#           't-shirt': 2,
#           'sorry.': 1,
#           'Maze,': 1,
#           'smiled,': 1,
#           'say.': 1,
#           'at': 13,
#           'more.': 2,
#           'entire': 1,
#           'Good': 1,
#           'tonight': 2,
#           'save': 1,
#           'crossed': 1,
#           'It': 5,
#           'sweats': 1,
#           'when': 8,
#           'glad.': 1,
#           'released': 1,
#           'begun.': 1,
#           'noticed': 1,
#           'good,': 2,
#           'had': 17,
#           'angry': 1,
#           'His': 2,
#           'grin': 1,
#           'anything,': 1,
#           'After': 2,
#           'garlic': 1,
#           'youre': 3,
#           'pulled': 3,
#           'past': 1,
#           'so': 11,
#           'Hed': 4,
#           'him.': 12,
#           'weight': 1,
#           'all': 15,
#           'club': 1,
#           'feel': 1,
#           'made': 1,
#           'here': 1,
#           'will': 2,
#           'grocery': 2,
#           'Love.': 1,
#           'like': 2,
#           'about?': 1,
#           'sat': 5,
#           'box?': 1,
#           'gave': 2,
#           'wrong?': 1,
#           'didnt.': 1,
#           'too,': 1,
#           'if': 3,
#           'adoptive': 1,
#           'shuddered': 2,
#           'She': 5,
#           'suddenly': 1,
#           'understood': 2,
#           'someone': 3,
#           'men.': 2,
#           'hadnt': 2,
#           'talking': 2,
#           'explained': 1,
#           'what': 22,
#           'tears': 1,
#           'well.': 1,
#           'day': 1,
#           'tell': 10,
#           'stopped': 1,
#           'way,': 1,
#           'shifted': 1,
#           'uncle.': 1,
#           'mine': 4,
#           'dont': 7,
#           'Its': 6,
#           'chewed': 1,
#           'week.': 2,
#           'In': 1,
#           'few': 3,
#           'get': 3,
#           'forgiveness': 1,
#           'blood.': 1,
#           'come': 6,
#           'raised': 2,
#           'inner': 1,
#           'upstairs.': 1,
#           'against': 2,
#           'would': 10,
#           'grocery,': 1,
#           'kind': 1,
#           'each': 3,
#           'sound,': 1,
#           'Who': 1,
#           'bite.': 2,
#           'groceries': 1,
#           'decided': 1,
#           'doesnt': 2,
#           'heard': 9,
#           'over?': 1,
#           'use': 1,
#           'sight.': 1,
#           'storm': 1,
#           'eased': 1,
#           'hat': 1,
#           'Im': 9,
#           'arms,': 1,
#           'arm.': 2,
#           'finished': 1,
#           'washed': 1,
#           'as': 13,
#           'Flicking': 1,
#           'matter': 1,
#           'ask': 2,
#           'shut': 1,
#           'that.': 5,
#           'ajar': 1,
#           'down': 6,
#           'bed': 3,
#           'slightly': 1,
#           'spent': 1,
#           'awhile.': 1,
#           'previously': 1,
#           'damn': 1,
#           'need': 8,
#           'finger': 1,
#           'pair': 1,
#           'been': 3,
#           'other': 2,
#           'messages.': 1,
#           'found': 2,
#           'while': 1,
#           'believed': 2,
#           'something': 3,
#           'even': 8,
#           'phone.': 1,
#           'asked': 3,
#           'dont.': 1,
#           'killed': 2,
#           'off': 5,
#           'wasnt': 2,
#           'fuel': 1,
#           'evening.': 1,
#           'end': 2,
#           'me': 36,
#           'Always': 2,
#           'also': 2,
#           'chest.': 2,
#           'care': 3,
#           'uncles': 1,
#           'letting': 1,
#           'isnt.': 1,
#           'sight': 1,
#           'her.': 2,
#           'some': 6,
#           'nothing': 2,
#           'jeans': 1,
#           'keep': 1,
#           'anyone.': 1,
#           'babying': 1,
#           'you': 18,
#           'Afterward': 1,
#           'days,': 1,
#           'family': 2,
#           'is': 3,
#           'Go.': 1,
#           'head': 1,
#           'mind': 2,
#           'Band-': 1,
#           'naturally': 1,
#           'I': 173,
#           'Tell': 1,
#           'stemmed': 1,
#           'rested': 2,
#           'guess': 1,
#           'pushed': 1,
#           'forward': 1,
#           'Perfect.': 1,
#           'cut': 2,
#           'us.': 2,
#           'Tomorrow': 1,
#           'rubbed': 2,
#           'shower': 2,
#           'harm.': 1,
#           'worked': 1,
#           'Crap,': 1,
#           'relaxed': 1,
#           'taking': 4,
#           'spend': 2,
#           'know,': 2,
#           'grasped': 1,
#           'better': 3,
#           'stroked': 2,
#           'see': 4,
#           'grabbed': 6,
#           'people': 1,
#           'long.': 1,
#           'face': 7,
#           'cell.': 1,
#           'leaned': 1,
#           'stood': 3,
#           'followed': 1,
#           'room.': 2,
#           'from': 9,
#           'needed.': 1,
#           'chose.': 1,
#           'now.': 3,
#           'babe.': 4,
#           'earlier': 1,
#           'much': 2,
#           'There': 3,
#           'since': 1,
#           'new': 1,
#           'understandably': 1,
#           'look': 2,
#           'arm,': 1,
#           'cheese,': 1,
#           'relief.': 1,
#           'reach': 1,
#           'creep': 1,
#           'box': 1,
#           'kinds': 1,
#           'deep.': 1,
#           'tests': 1,
#           'laughed.': 1,
#           'too.': 1,
#           'delicious.': 1,
#           'dyer,': 1,
#           'phone': 4,
#           'disappeared.': 1,
#           'wishes': 1,
#           'be': 13,
#           'a': 54,
#           'days': 3,
#           'Tsang.': 2,
#           'hold': 1,
#           'cleared': 1,
#           'answering.': 1,
#           'slept': 1,
#           'Tsang': 9,
#           'down.': 1,
#           'figured': 1,
#           'sadly': 1,
#           'asked.': 3,
#           'have': 10,
#           'refused': 1,
#           'At': 1,
#           'buzzing': 1,
#           'Whatwhat': 1,
#           'Are': 1,
#           'idea,': 1,
#           'croaked': 1,
#           'man': 1,
#           'marks': 1,
#           'there.': 3,
#           'balls': 1,
#           'long': 2,
#           'Without': 1,
#           'cared': 1,
#           'fell': 1,
#           'challenge': 1,
#           'only': 4,
#           'open': 2,
#           'bedroom.': 2,
#           'core.': 1,
#           'homicide.': 1,
#           'cups': 1,
#           'Aid': 1,
#           'chair': 1,
#           'We': 4,
#           'Id': 11,
#           'glad': 1,
#           'wallet': 1,
#           'That': 1,
#           'reached': 1,
#           'though': 1,
#           'out.': 3,
#           'it?': 1,
#           'Listen.': 1,
#           'Youre': 1,
#           'guy': 1,
#           'wet.': 1,
#           'despair': 1,
#           'about': 5,
#           'right': 3,
#           'hip.': 1,
#           'this.': 3,
#           'feeling?': 1,
#           'home.': 3,
#           'shy': 1,
#           'there': 3,
#           'actions': 1,
#           'agreed.': 2,
#           'Enclosed': 1,
#           'heard.': 1,
#           'mac': 1,
#           'stuff': 2,
#           'fall': 1,
#           'breathed': 1,
#           'bathroom': 3,
#           'pace.': 1,
#           'What': 1,
#           'probably': 1,
#           'rolled': 1,
#           'top': 1,
#           'boots,': 1,
#           'Maze.': 2,
#           'do': 10,
#           'dinner': 1,
#           'idea': 1,
#           'okay?': 2,
#           'breakfast.': 1,
#           'way': 3,
#           'sure': 7,
#           'happened.': 1,
#           'Dante': 7,
#           'Never.': 1,
#           'you.': 5,
#           'couch': 1,
#           'table': 1,
#           'being': 1,
#           'bagel': 1,
#           'couldnt,': 1,
#           'anything': 1,
#           'pick': 1,
#           'try': 2,
#           'excited': 1,
#           'were,': 1,
#           'pulsed': 1,
#           'into': 14,
#           'vacation.': 1,
#           'My': 6,
#           'relationship.': 1,
#           'for': 20,
#           'cops': 1,
#           'needs': 1,
#           'gathered': 1,
#           'placed': 4,
#           'phone,': 1,
#           'Other': 2,
#           'reacted': 1,
#           'bedroom': 3,
#           'Everything': 2,
#           'more': 3,
#           'The': 8,
#           'custody.': 1,
#           'his.': 1,
#           'Mark': 2,
#           'minute.': 1,
#           'He': 50,
#           'roomnaked.': 1,
#           'bread': 1,
#           'room': 1,
#           'something.': 1,
#           'slaving': 1,
#           'hear': 2,
#           'Triad.': 1,
#           'world.': 1,
#           'Joes': 1,
#           'gentle': 1,
#           'but': 14,
#           'say': 2,
#           'detective.': 1,
#           'always': 2,
#           'Then': 3,
#           'wait': 2,
#           'shut,': 1,
#           'stepped': 3,
#           'floor.': 1,
#           'walking': 1,
#           'just': 7,
#           'under': 1,
#           'inside': 4,
#           'asking': 1,
#           'laid': 1,
#           'be.': 2,
#           'squeezed': 1,
#           'sex': 1,
#           'run': 4,
#           'features.': 1,
#           'love': 5,
#           'face.': 2,
#           'friend.': 1,
#           'very': 1,
#           'huh?': 1,
#           'up': 11,
#           'trust': 1,
#           'If': 2,
#           'continued': 1,
#           'right.': 2,
#           'kiss': 1,
#           'salve': 1,
#           'suspected': 2,
#           'readied': 1,
#           'part': 3,
#           'suicide?': 1,
#           'everyone': 1,
#           'afterward': 1,
#           'hed': 7,
#           'deep': 2,
#           'accepted': 1,
#           'morning': 2,
#           'sense': 1,
#           'store': 1,
#           'closest': 1,
#           'Never': 2,
#           'tea.': 1,
#           'happy': 1,
#           'did': 3,
#           'understand,': 1,
#           'spoken': 2,
#           'its': 2,
#           'slice': 1,
#           'dove': 1,
#           'Maze': 23,
#           'None': 1,
#           'suspect': 1,
#           'in.': 1,
#           'protected': 1,
#           'word': 1,
#           'or': 4,
#           'headed': 1,
#           'Chapter': 1,
#           'pieces': 1,
#           'gone.': 1,
#           'Ill': 8,
#           'should': 2,
#           'really': 4,
#           'thing': 2,
#           'dropping': 1,
#           'break': 1,
#           'came': 4,
#           'bowl': 1,
#           'actually': 2,
#           'lowered': 2,
#           'ten': 1,
#           'minute': 1,
#           'opened': 5,
#           'most': 2,
#           'still': 2,
#           'About': 1,
#           'Hes': 1,
#           'cook.': 2,
#           'going': 8,
#           'onto': 2,
#           'rubbing': 1,
#           'stop': 1,
#           'legs': 1,
#           'place.': 2,
#           'everything': 6,
#           'wont': 2,
#           'betrayal': 1,
#           'wont.': 1,
#           'was': 42,
#           'deserved': 1,
#           'entered': 2,
#           'back.': 1,
#           'kitchen': 1,
#           'slipped': 1,
#           'kept': 1,
#           'take': 3,
#           'any': 2,
#           'swallowed': 1,
#           'might': 2,
#           'again.': 2,
#           'shoulders.': 1,
#           'stored.': 1,
#           'every': 1,
#           'God': 2,
#           'mom.': 1,
#           'on.': 2,
#           'Band-Aid.': 1,
#           'stroke,': 1,
#           'entwined': 1,
#           'They': 5,
#           'out': 14,
#           'chosen': 1,
#           'RBA': 1,
#           'Dante.': 1,
#           'commit': 1,
#           'help': 1,
#           'things': 1,
#           'dream': 1,
#           'read': 1,
#           'took': 10,
#           'hugged': 1,
#           'welling': 1,
#           'him?': 1,
#           'enough': 1,
#           'favorite': 1,
#           'called': 3,
#           'way.': 2,
#           'hands': 2,
#           'Were': 1,
#           'water': 1,
#           'wondered': 1,
#           'cook': 3,
#           'true.': 2,
#           'Ivy.': 1,
#           'held': 4,
#           'away': 4,
#           'back': 11,
#           'already': 3,
#           'vacation': 1,
#           'my': 45,
#           'condo.': 1,
#           'over': 8,
#           'some.': 1,
#           'one': 4,
#           'beach': 1,
#           'food.': 2,
#           'backroom.': 1,
#           'sitting': 1,
#           'direction.': 1,
#           'his': 38,
#           'rumbled.': 1,
#           'breast': 1,
#           'questions.': 1,
#           'suspect.': 1,
#           'close': 2,
#           'again': 1,
#           'How': 1,
#           'rise': 1,
#           'same.': 1,
#           'smiled.': 2,
#           'toward': 1,
#           'the': 99,
#           'pause,': 1,
#           'outer': 1,
#           'worse,': 1,
#           'Do': 1,
#           'later,': 1,
#           'he': 44,
#           'limped': 1,
#           'it': 22,
#           'hand.': 1,
#           'bag.': 1,
#           'answered': 1,
#           'fixing': 1,
#           'Mazes': 2,
#           'Fine,': 1,
#           'salad,': 1,
#           'far': 1,
#           'filled': 1,
#           'make': 7,
#           'cup': 1,
#           'choked': 1,
#           'lay': 2,
#           'Nineteen': 1,
#           'good': 2,
#           'scenarios.': 1,
#           'gang': 1,
#           'talk': 3,
#           'poor': 1,
#           'went': 7,
#           'here?': 2,
#           'side.': 3,
#           'causing': 1,
#           'smiled': 5,
#           'led': 1,
#           'breath.': 1,
#           'home': 1,
#           'names.': 1,
#           'wants': 1,
#           'surrounded': 1,
#           'gray': 2,
#           'compelled': 1,
#           'said.': 3,
#           'seemed': 2,
#           'spoke': 2,
#           'couple': 2,
#           'What!': 1,
#           'an': 1,
#           'show': 1,
#           'Did': 2,
#           'performed': 1,
#           'runs.': 1,
#           'love,': 1,
#           'change': 1,
#           'This': 2,
#           'protect': 1,
#           'family,': 1,
#           'laughed': 2,
#           'Everyone': 1,
#           'sweatshirt.': 1,
#           'understand.': 1,
#           'another': 2,
#           'sighed.': 2,
#           'history.': 1,
#           'bagels': 1,
#           'of': 45,
#           'eat.': 2,
#           'edge': 1,
#           'matter.': 1,
#           'together': 1,
#           'while.': 1,
#           'vague': 1,
#           'left.': 1,
#           'theres': 1,
#           'best': 2,
#           'completely,': 1,
#           'night.': 5,
#           'waist.': 1,
#           'Yeah.': 1,
#           'phones.': 1,
#           'go': 7,
#           'knew': 7,
#           'quietly': 1,
#           'things,': 1,
#           'ago': 2,
#           'together.': 2,
#           'mothers': 1,
#           'got': 7,
#           'When': 2,
#           'want': 5,
#           'sleeping': 1,
#           'stall': 1,
#           'with': 10,
#           'fix': 1,
#           'and': 106,
#           'both': 6,
#           'From': 1,
#           'fights': 1,
#           'they': 5,
#           'hall': 1,
#           'Will.': 1,
#           'idea.': 1,
#           'Will': 6,
#           'thought': 6,
#           'up,': 1,
#           'waist': 1,
#           'shoulder,': 1,
#           'ran': 1,
#           'Go': 1,
#           'almost': 1,
#           'car': 1,
#           'less': 1,
#           'please,': 1,
#           'short': 1,
#           'put': 9,
#           'ignored': 1,
#           'head.': 1,
#           'Hows': 1,
#           'looked': 1,
#           'two': 1,
#           'removed': 1,
#           'Is': 2,
#           'breathing': 1,
#           'wouldnt,': 1,
#           'yesterday.': 1,
#           'Not': 3,
#           'muscles': 1,
#           'lit': 1,
#           'couldnt': 1,
#           'stand': 1,
#           'hand': 3,
#           'You': 5,
#           'built': 1,
#           'questions,': 1,
#           'able': 2,
#           'smirked.': 1,
#           'shorts.': 1,
#           'whatever': 1,
#           'voice.': 1,
#           'know': 9,
#           'day.': 1,
#           'lying': 2,
#           'heat': 1,
#           'could': 9,
#           'myself.': 1,
#           'dinner.': 1,
#           'himself': 4,
#           'festival.': 1,
#           'willing': 1,
#           'Uncle': 1,
#           'Dantes': 1,
#           'who': 2,
#           'affected': 1,
#           'package.': 1,
#           'week': 1,
#           'war': 1,
#           'details.': 2,
#           'Yes,': 1,
#           'plenty': 1,
#           'fine': 1,
#           'waited': 3,
#           'Yeah,': 1,
#           'must': 1,
#           'know.': 4,
#           'about.': 1,
#           'Trust': 1,
#           'clit.': 1,
#           'protective': 1,
#           'happen': 1,
#           'midday': 1,
#           'Thank': 1,
#           'said': 1,
#           'then': 10,
#           'leave': 1,
#           'washing': 1,
#           'Crap.': 1,
#           'she': 2,
#           'big': 1,
#           'your': 4,
#           'watched': 2,
#           'meant': 1,
#           'Love': 1,
#           'that': 12,
#           'rest': 1,
#           'laundry': 1,
#           'drop': 1,
#           'robe': 1,
#           'this': 5,
#           'stay': 2,
#           'in': 18,
#           'man.': 1,
#           'we': 14,
#           'blinked': 1,
#           'foot?': 1,
#           'here.': 4,
#           'uttered': 1,
#           'involved': 1,
#           'their': 1,
#           'affect': 1,
#           'A': 3,
#           'let': 4,
#           'putting': 1,
#           'hurt': 1,
#           'cover.': 1,
#           'Whats': 2,
#           'youve': 1,
#           'lower': 1,
#           'all.': 2,
#           'Gourmet': 1,
#           'Sit,': 1,
#           'sends': 1,
#           'safe': 1,
#           'call.': 1,
#           'seated': 1,
#           'tattoo': 1,
#           'Ivy': 1,
#           'Joe': 3,
#           'decide,': 1,
#           'Besides,': 1,
#           'did.': 2,
#           'around': 4,
#           'no': 3,
#           'arms': 3,
#           'burned': 1,
#           'how': 3,
#           'causality.': 1,
#           'bathroom.': 1,
#           'sword.': 1,
#           'stomach': 2,
#           'nodded.': 1,
#           'why': 3,
#           'table.': 3,
#           'deeper': 1,
#           'heights': 1,
#           'myself': 3,
#           'killed.': 1,
#           'passion': 1,
#           'share.': 1,
#           'aroused': 1,
#           'arm': 4,
#           'Joe,': 1,
#           'stared': 2,
#           'cliff.': 1,
#           'are': 4,
#           'wed': 4,
#           'By': 2,
#           'until': 6,
#           'earlier.': 2,
#           'awoke': 1,
#           'possible': 1,
#           'time,': 1,
#           'exactly': 2,
#           'than': 4,
#           'clit': 1,
#           'now': 1,
#           'closeness': 2,
#           'best.': 1,
#           'murmured': 1,
#           'through': 3,
#           'wouldnt': 2,
#           'news': 1,
#           'her': 4,
#           'thered': 1,
#           'What?': 1,
#           'kitchen.': 1,
#           'day,': 1,
#           'not.': 1,
#           'saw': 2,
#           'them': 9,
#           'eyes.': 2,
#           'immediately': 1,
#           'Yes.': 2,
#           'near': 1,
#           'identify': 1,
#           'Family': 1,
#           'same': 2,
#           'sadness': 3,
#           'comfort': 2,
#           'it.': 10,
#           'gone': 2,
#           'didnt': 6,
#           'festival,': 1,
#           'rule': 1,
#           'send': 1,
#           'right?': 2,
#           'before': 7,
#           'text': 2,
#           'Marks': 1,
#           'little': 1,
#           'up.': 4,
#           'Theyre': 1,
#           'mom,': 1,
#           'bed.': 3,
#           'candles': 1,
#           'where': 1,
#           'quickly': 1,
#           'because': 1,
#           'mom': 1,
#           'With': 1,
#           'room,': 1,
#           'sleep.': 1,
#           'met': 1,
#           'us': 3,
#           'faster': 1,
#           'sound.': 1,
#           'smile': 1,
#           'moved': 3,
#           'Oh': 1,
#           'forget': 1,
#           'Hopefully,': 1,
#           'cast': 1,
#           'think': 7,
#           'keys': 1,
#           'decide': 1,
#           'anyway.': 1,
#           'demand': 1,
#           'make.': 1,
#           'on?': 1,
#           'him,': 1,
#           'picked': 1,
#           'three': 1,
#           'morning,': 1,
#           'for.': 1,
#           'spread': 1,
#           'me.': 18,
#           'turned': 5,
#           'else': 2,
#           'sensation': 1,
#           'relax': 1,
#           'summit': 1,
#           'door.': 2,
#           'needed': 9,
#           'knock': 2,
#           'decision.': 1,
#           'drinking': 1,
#           'beat': 1,
#           'loved.': 1,
#           'Thats': 2,
#           'by': 3,
#           'pull': 1,
#           'taken': 2,
#           'dresser.': 1,
#           'stabbed': 1,
#           'neck.': 1,
#           'dawn.': 1,
#           'suicide.': 1,
#           'description': 2,
#           'stove': 1,
#           'fine.': 7,
#           'And': 6,
#           'suckled': 1,
#           'list': 1,
#           'love.': 3,
#           'No.': 1,
#           'other.': 1,
#           'texts': 1,
#           'One': 2,
#           'answer': 1,
#           'mess': 1,
#           'belly.': 1,
#           'give': 4,
#           'Hey,': 1,
#           'wanted': 13,
#           'But': 7,
#           'fingers': 3,
#           'time': 6,
#           'loved': 1,
#           'thats': 2,
#           'ever': 2,
#           'five': 1,
#           'eyes': 2,
#           'identified': 1,
#           'our': 6,
#           'Bev': 1,
#           'to': 108,
#           'Before': 1,
#           'Later': 1,
#           'then.': 2,
#           'higher': 1,
#           'trying': 1,
#           'him': 26,
#           'shock': 1,
#           'dragon': 1,
#           'Ah,': 1,
#           'Well,': 1,
#           'machine': 1,
#           'own': 1,
#           'hair.': 1,
#           'hung': 2,
#           'power': 1,
#           'morgue.': 1,
#           'late.': 1,
#           'doing': 2,
#           'cause': 1,
#           'Some': 2,
#           'normal': 1,
#           'not': 7,
#           'check': 1,
#           'really,': 1,
#           'great': 1,
#           'Giving': 1,
#           'voices': 1,
#           'moment.': 1,
#           'body.': 1,
#           'pretended': 2,
#           'But,': 1,
#           'lips.': 1,
#           'next': 2,
#           'on': 31,
#           'without': 2,
#           'opportunity': 1,
#           'sigh': 1,
#           'training': 1,
#           'plates': 1,
#           'never': 2,
#           'happened': 4,
#           'yeah.': 1,
#           'counted': 1,
#           'tonight.': 1,
#           'Ivy?': 1,
#           'baby.': 1,
#           'later': 1,
#           'were': 6,
#           'prayed': 1,
#           'safe,': 1,
#           'beer': 1,
#           'seen': 2,
#           'alone': 1,
#           'looks': 1,
#           'me,': 5,
#           'bodyguards': 2,
#           'honey.': 1,
#           'abducted.': 1,
#           'understand': 1,
#           'gasped': 1,
#           'learn': 1,
#           'left': 4,
#           'behind': 2,
#           'sorry': 1,
#           'door': 7,
#           'spasm.': 1,
#           'making': 1,
#           'knows': 1,
#           'thinking': 1,
#           'good.': 2,
#           'Catching': 1,
#           'liking': 1,
#           'wore': 1,
#           'body': 1,
#           'off,': 1,
#           'working': 1,
#           'lifted': 1,
#           'straight': 2,
#           'dare': 1,
#           'hard.': 1,
#           'evening': 1,
#           'piece': 1,
#           'side': 1,
#           'Mmm,': 1,
#           'Ive': 1,
#           'door,': 1,
#           'Oh,': 3,
#           ...})

# %%
string.printable[:-5]+string.printable[-4]
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \n'

# %%
from bs4 import BeautifulSoup

# %%
def html2txt(html):
    soup = BeautifulSoup(html,"lxml")
    return soup.get_text()
